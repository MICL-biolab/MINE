# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn2

# %%
def get_significant(file_path):
    significants = []
    with open(file_path, "r") as f:
        datas = f.readlines()
        for data in datas[1:]:
            data = data.split()
            x, y = int(int(data[1])/1000), int(int(data[3])/1000)
            p_value, q_value = float(data[5]), float(data[6])
            concat = int(data[4])
            significants.append((x, y, p_value, q_value, concat))
    return significants

def cal_significant(significants, proportion):
    test = np.array(significants)
    
    def _filter(_values, max_nums, test):
        values_sort_index = _values.argsort()
        values_min_numbers_index = values_sort_index[max_nums-1]
        p = max_nums
        values_min_indexs = _values.argsort()[:p-1]
        _test = test[values_min_indexs, :]
        return _test

    _p_values = test[:, 2]
    _test = _filter(_p_values, int(_p_values.shape[0]*proportion), test)
    _q_values = _test[:, 3]
    _test = _filter(_q_values, int(_q_values.shape[0]*proportion), _test)
    return _test

def cal_significant_test(significants, proportion):
    test = np.array(significants)

    test = test[np.argsort(test[:, 2])]
    _test = np.zeros((int(test.shape[0]*proportion), 5))
    significant_set = set()
    index = 0
    for i in range(test.shape[0]):
        x, y = int(test[i, 0]), int(test[i, 1])
        flag = False
        for _x in range(x-4, x+5):
            for _y in range(y-4, y+5):
                if (_x, _y) in significant_set:
                    flag = True
                    break
            if flag:
                break
        if flag:
            continue
        significant_set.add((x, y))
        _test[index] = test[i]
        index += 1
        if index > _test.shape[0] - 1:
            break
    
    def _filter(_values, max_nums, test):
        values_sort_index = _values.argsort()
        values_min_numbers_index = values_sort_index[max_nums-1]
        p = max_nums
        values_min_indexs = _values.argsort()[:p-1]
        _test = test[values_min_indexs, :]
        return _test

    _q_values = _test[:, 3]
    _test = _filter(_q_values, int(_q_values.shape[0]*proportion), _test)
    return _test

def show_venn(enhanced_sig_set, hr_sig_set):
    venn2(subsets = [hr_sig_set, enhanced_sig_set], set_labels = ('1kb', 'enhanced'), set_colors=((247/255, 129/255, 191/255), (51/255, 160/255, 44/255)))
    plt.show()

# %%
analyse_path = '/data1/lmh_data/MINE/GM12878_ATAC_H3K27ac_H3K4me3/analyse/GM12878_ATAC_H3K27ac_H3K4me3'
enhanced_path = os.path.join(analyse_path, 'experiment', 'loop', 'enhanced')
hr_path = os.path.join(analyse_path, 'experiment', 'loop', 'hr')
auxiliary_files_path = '/data1/lmh_data/MINE/source/GM12878'
proportion = 0.015

# 未去交集的全部sig
enhanced_sigs = set()
hr_sigs = set()
# 去交集的全部sig
all_enhanced_sig = dict()
all_hr_sig = dict()
for chr in range(1, 23):
    enhanced_file_path = os.path.join(enhanced_path, 'chr{}_1000b'.format(chr), 'outputs_2_100', 'FitHiC.spline_pass1.res1000.significances.txt')
    hr_file_path = os.path.join(hr_path, 'chr{}_1000b'.format(chr), 'outputs_2_100', 'FitHiC.spline_pass1.res1000.significances.txt')
    enhanced_sig = cal_significant_test(get_significant(enhanced_file_path), proportion)
    hr_sig = cal_significant(get_significant(hr_file_path), proportion)
    
    _enhanced_sig = set(list(map(tuple, np.array(enhanced_sig)[:, :2])))
    _hr_sig = set(list(map(tuple, np.array(hr_sig)[:, :2])))
    show_venn(_enhanced_sig, _hr_sig)
    # 去交集
    new_enhanced_sig = _enhanced_sig - _hr_sig
    new_hr_sig = _hr_sig - _enhanced_sig
    
    all_enhanced_sig[chr] = new_enhanced_sig
    all_hr_sig[chr] = new_hr_sig
    
    for sig in _enhanced_sig:
        _sig = list(sig)
        _sig.append('chr{}'.format(chr))
        enhanced_sigs.add(tuple(_sig))
    for sig in _hr_sig:
        _sig = list(sig)
        _sig.append('chr{}'.format(chr))
        hr_sigs.add(tuple(_sig))

# %%
show_venn(enhanced_sigs, hr_sigs)

# %%
attentions = 50
center = attentions - 1

def read_chiqseq_file(path):
    _peaks = dict()
    with open(path)as f:
        for line in f:
            datas = line.strip().split()
            left, right = int(int(datas[1])/1000), int(int(datas[2])/1000)
            peaks = list(range(left, right+1))
            if datas[0] not in _peaks.keys():
                _peaks[datas[0]] = set()
            for i in peaks:
                _peaks[datas[0]].add(i)
    return _peaks

def get_hit_indicators(significants, peaks):
    distance = np.zeros(attentions*2-1)
    
    for sig in significants:
        x, y = int(sig[0]), int(sig[1])
        for i in range(attentions):
            if (x+i) in peaks or (y+i) in peaks:
                distance[center-i] += 1
            if i != 0 and((x-i) in peaks or (y-i) in peaks):
                distance[center+i] += 1
            if (x+i) in peaks or (x-i) in peaks or (y+i) in peaks or (y-i) in peaks:
                break
    return distance

def show(x, mine_result, hr_result):
    sns.set_style("whitegrid") 
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), sharey=True)
    axes.grid(False)
    axes.plot(x, mine_result, color=(51/255, 160/255, 44/255), label='mine')
    axes.plot(x, hr_result, color=(177/255, 89/255, 40/255), label='hr')

    plt.xlabel('distance')
    plt.ylabel('nums')
    plt.legend()
    plt.show()

def figure(chip_seq_path):
    all_enhanced_result = np.zeros(attentions*2-1)
    all_hr_result = np.zeros(attentions*2-1)

    for chr in range(1, 23):
        _peaks = read_chiqseq_file(chip_seq_path)
        enhanced_result = get_hit_indicators(all_enhanced_sig[chr], _peaks['chr{}'.format(chr)])
        hr_result = get_hit_indicators(all_hr_sig[chr], _peaks['chr{}'.format(chr)])

        all_enhanced_result += enhanced_result
        all_hr_result += hr_result

    show(list(range(-attentions+1, attentions)), all_enhanced_result, all_hr_result)

# %%
tss_file_path = os.path.join(auxiliary_files_path, 'Homo_sapiens.GRCh38.104.chr.gff3')

def get_tss_gene_info(gene_biotype='protein_coding'):
    gene_location = dict()
    gene_info = dict()
    with open(tss_file_path, "r") as f:
        datas = f.readlines()
        for data in datas[9:]:
            data = data.split('\t')
            if len(data) < 9:
                continue
            if data[2] != 'gene' or data[8].find(gene_biotype) == -1:
                continue
            if data[6] == '+':
                _location = data[3]
            elif data[6] == '-':
                _location = data[4]
            else:
                print('error')
            if not data[0].isdigit():
                continue
            chromosome = int(data[0])
            if chromosome not in gene_location:
                gene_location[chromosome] = set()
            gene_location[chromosome].add(int(int(_location)/1000))
            
            _tmp = data[-1].split('Name=')
            if len(_tmp) < 2:
                continue
            gene_names = _tmp[1].split(';')[0]
            gene_ids = data[-1].split('ID=')[1].split(',')[0].split(';')[0]
            
            if chromosome not in gene_info:
                gene_info[chromosome] = set()
            gene_info[chromosome].add((int(int(_location)/1000), gene_names, gene_ids, data[-1].replace('\n', '')))
    return gene_location, gene_info

def figure_tss(locations):
    all_enhanced_result = np.zeros(attentions*2-1)
    all_hr_result = np.zeros(attentions*2-1)

    for chr in range(1, 23):
        if chr not in locations:
            continue
        enhanced_result = get_hit_indicators(all_enhanced_sig[chr], locations[chr])
        hr_result = get_hit_indicators(all_hr_sig[chr], locations[chr])

        all_enhanced_result += enhanced_result
        all_hr_result += hr_result

    show(list(range(-attentions+1, attentions)), all_enhanced_result, all_hr_result)

# %%
figure_tss(get_tss_gene_info('protein_coding')[0])

# %%
figure_tss(get_tss_gene_info('pseudogene')[0])

# %%
def get_hit_genes(significants, gene_info, genes_loop_nums):
    genes = set()
    for sig in significants:
        x, y = int(sig[0]), int(sig[1])
        for _info in gene_info:
            if abs(x-_info[0])<3 or abs(y-_info[0])<3:
                if _info[1] not in genes_loop_nums:
                    genes_loop_nums[_info[1]] = 1
                else:
                    genes_loop_nums[_info[1]] += 1
                genes.add((_info[1], _info[2], _info[3]))
    return genes, genes_loop_nums

def get_hit_gene_names(significants, gene_biotype='protein_coding'):
    gene_info = get_tss_gene_info(gene_biotype)[1]
    all_genes = set()
    genes_loop_nums = dict()
    for chr in range(1, 23):
        genes, genes_loop_nums = get_hit_genes(significants[chr], gene_info[chr], genes_loop_nums)
        all_genes = all_genes | genes
    return all_genes, genes_loop_nums

# %%
mine_hit_genes, mine_genes_loop_nums = get_hit_gene_names(all_enhanced_sig, gene_biotype='protein_coding')
mine_hit_genes = list(mine_hit_genes)
mine_hit_genes = np.array(mine_hit_genes)
print(len(mine_hit_genes))
print(mine_genes_loop_nums.keys())
# Out:
# 2454
# dict_keys(['TOR1AIP1', 'KIAA0319L', 'NCDN', 'PLEKHO1', 'FAM102B', 'FCGR2B', 'PSMB2', 'STMN1', 'FCRLB', 'TNFAIP8L2', 'SCNM1', 'CHD1L', 'FMO5', 'PRKAB2', 'RBM8A', 'ARID1A', 'CR1', 'KCNC4', 'TOMM40L', 'APOA2', 'FCER1G', 'NOTCH2NLC', 'RGS1', 'NEK7', 'SMG7', 'S100A10', 'NUAK2', 'SELL', 'GPR89A', 'LRRC42', 'HSPB11', 'GATAD2B', 'PKN2', 'FCRL6', 'HJV', 'POLR3GL', 'ANKRD34A', 'MCL1', 'GPR3', 'GFI1', 'HNRNPU', 'ZBTB41', 'CHIT1', 'MYCL', 'ACKR1', 'FCGR2A', 'PIK3R3', 'NPR1', 'PAFAH2', 'FCGR3A', 'PMF1-BGLAP', 'PMF1', 'SEMA4A', 'FCN3', 'ANKRD35', 'RUNX3', 'AIDA', 'BROX', 'SLAMF6', 'LIX1L', 'SMIM12', 'RABGGTB', 'RASSF5', 'GGPS1', 'TBCE', 'ARID4B', 'VPS45', 'GNAI3', 'AMPD2', 'PPP1R15B', 'PIK3C2B', 'PEX11B', 'IFI44L', 'NUDT17', 'DIPK1A', 'ZNF678', 'GNB1', 'AP4B1', 'DCLRE1B', 'RSBN1', 'CTSE', 'BTBD19', 'ITGA10', 'PPIAL4A', 'URB2', 'TAF5L', 'CDC73', 'RO60', 'HAX1', 'SHISA4', 'RNPEP', 'RSRP1', 'TMEM50A', 'SLC30A1', 'GALE', 'FUCA1', 'MFSD2A', 'NASP', 'SRGAP2B', 'FAM72D', 'PIGV', 'HSPA6', 'RXFP4', 'ASH1L', 'TRIM46', 'KRTCAP2', 'HIPK1', 'CDK11A', 'PPIAL4G', 'CD164L2', 'PDZK1', 'EYA3', 'NBPF15', 'CTTNBP2NL', 'SH3BGRL3', 'CRYBG2', 'ID3', 'SLC27A3', 'ILF2', 'TLR5', 'UCK2', 'TMCO1', 'FCGR3B', 'LUZP1', 'ACBD3', 'CDK11B', 'E2F2', 'CEP350', 'PEX19', 'ADAMTSL4', 'ZNF281', 'B3GALT6', 'SDF4', 'GADD45A', 'ELF3', 'SLC35E2B', 'BSND', 'NBPF9', 'TAGLN2', 'EFCAB2', 'AVPR1B', 'ACADM', 'LRRC8C', 'OTUD7B', 'SF3B4', 'CNR2', 'OR2T5', 'KMO', 'MCOLN2', 'LRRC8B', 'NBPF26', 'NOTCH2NLR', 'CD160', 'PIAS3', 'RLF', 'RAB3B', 'PPM1J', 'TAFA3', 'ZMPSTE24', 'GNL2', 'PSRC1', 'GNG5', 'SPATA1', 'CTBS', 'KHDC4', 'LAMTOR5', 'RBM15', 'EIF3I', 'TMEM234', 'THEM4', 'LCK', 'GNAT2', 'C1orf109', 'CDCA8', 'HAO2', 'OR2T3', 'ABCB10', 'ITPKB', 'S100A2', 'DAB1', 'OMA1', 'RHD', 'PI4KB', 'PSMB4', 'FH', 'IER5', 'ARHGEF2', 'HES3', 'ST7L', 'CAPZA1', 'RHOC', 'CD48', 'GABPB2', 'CDC42SE1', 'OR2T29', 'GPR89B', 'DYNLT4', 'WASF2', 'ZFP69B', 'TOR1AIP2', 'IQGAP3', 'H2AC21', 'H2BC21', 'H2AC20', 'BOLA1', 'NEGR1', 'PERM1', 'MYBPHL', 'THRAP3', 'MMP23B', 'H3C13', 'H2BC18', 'NBPF19', 'LYST', 'WNT2B', 'ENSA', 'PPIAL4D', 'SESN2', 'CFAP126', 'TXNIP', 'SF3A3', 'DNAI3', 'SH3BP5L', 'PGBD2', 'HDAC1', 'XKR8', 'INSRR', 'DENND4B', 'ANKRD13C', 'EGLN1', 'SRGAP2C', 'SDHC', 'OR2T34', 'IKBKE', 'CCDC163', 'MMACHC', 'YIPF1', 'DIO1', 'TESK2', 'MATN1', 'ASPM', 'CCDC18', 'TMED5', 'H3-3A', 'TENT5C', 'FAM189B', 'BATF3', 'FMOD', 'KIF2C', 'AHDC1', 'KCNA3', 'CHMP3', 'GPD2', 'NR4A2', 'STK17B', 'USP34', 'ANKRD36B', 'STAT4', 'DPYSL5', 'DUSP2', 'FOXN2', 'NMUR1', 'IKZF2', 'ANKRD36', 'XRCC5', 'ACTR3', 'ERMN', 'CFLAR', 'ANKRD44', 'ACOXL', 'BUB1', 'IDH1', 'PIKFYVE', 'PLEK', 'ASTL', 'ACKR3', 'CATIP', 'ASDURF', 'ASNSD1', 'WIPF1', 'GPBAR1', 'INPP4A', 'RTP5', 'ATF2', 'AUP1', 'HTRA2', 'WDFY1', 'UBE2F', 'UBE2F-SCLY', 'IHH', 'SLC1A4', 'NABP1', 'HNRNPA3', 'PRLH', 'PRADC1', 'CCT7', 'SPATA3', 'STK11IP', 'SLC39A10', 'CCDC141', 'NFU1', 'MERTK', 'ATAD2B', 'UBXN2A', 'LBX2', 'BCL2L11', 'PDCD1', 'EML4', 'SDC1', 'SLC20A1', 'DTYMK', 'THAP4', 'ING5', 'ATG4B', 'RABL2A', 'MSGN1', 'GEN1', 'MTERF4', 'HDLBP', 'SEPTIN2', 'TMBIM1', 'TMEM87B', 'GFPT1', 'PPP1R7', 'PASK', 'PCBP1', 'HEATR5B', 'GPATCH11', 'PROC', 'ANKRD23', 'ANKRD39', 'CCL20', 'CUL3', 'RETREG2', 'CNPPD1', 'SPR', 'TLK1', 'ADRA2B', 'IL18RAP', 'LIMS1', 'SOS1', 'RHOQ', 'ATP6V1E2', 'CTDSP1', 'CCDC88A', 'DUSP28', 'C2orf92', 'ACTR1B', 'FAHD2B', 'COX5B', 'PTPN4', 'AQP12B', 'CAPN10', 'RRM2', 'ATOH8', 'NEURL3', 'ATP5MC3', 'CCDC142', 'TTC31', 'SOWAHC', 'SEPTIN10', 'RPIA', 'EIF2AK3', 'CAB39', 'RNF103', 'PTMA', 'SP110', 'POLR1B', 'ZNF514', 'ZNF2', 'CASP10', 'COL4A3', 'COL4A4', 'DPP4', 'ANAPC1', 'REL', 'ITSN2', 'GPR155', 'SEMA4C', 'SCN3A', 'PRKD3', 'FBXO36', 'FARP2', 'FAM240C', 'CLASP1', 'CNNM4', 'HTR2B', 'AFTPH', 'USP40', 'CD8A', 'KCMF1', 'DGUOK', 'ABHD1', 'SLC23A3', 'PELI1', 'SLC11A1', 'IL1A', 'D2HGDH', 'NT5DC4', 'SMC6', 'PREB', 'GPR55', 'SCN9A', 'CNOT11', 'TBC1D8', 'RAB10', 'C1GALT1C1L', 'THADA', 'CYS1', 'KANSL1L', 'TMEM198', 'CHPF', 'ARPC2', 'INO80D', 'COQ10B', 'PGAP1', 'MAL', 'GMCL1', 'CNOT9', 'USP37', 'BZW1', 'FAM126B',  ...

# %%
x = list(mine_genes_loop_nums.keys())
y = list(mine_genes_loop_nums.values())

sns.set_style("whitegrid") 
fig, axes = plt.subplots(nrows=1, ncols=1, sharey=True)
axes.grid(False)
axes.plot(x, y, color=(166/255, 206/255, 227/255), label='mine')

plt.xticks(rotation=90, fontsize=14)

# plt.ylim(0, 1)
plt.xlabel('gene_names')
plt.ylabel('nums')
# plt.xlim(0, len(significants))
plt.legend()
plt.show()

# %%
hr_hit_genes, hr_genes_loop_nums = get_hit_gene_names(all_hr_sig, gene_biotype='protein_coding')
hr_hit_genes = list(hr_hit_genes)
hr_hit_genes = np.array(hr_hit_genes)
print(len(hr_hit_genes))
print(hr_genes_loop_nums.keys())
# Out:
# 796
# dict_keys(['CDK11B', 'CDK11A', 'F13B', 'OR2T29', 'OR2G6', 'CACHD1', 'FPGT-TNNI3K', 'FPGT', 'LRRIQ3', 'FCGR1B', 'OR2T3', 'OR2T5', 'ZNF695', 'OR4F5', 'FCRL3', 'RHD', 'H2BC18', 'OR2T8', 'NBPF6', 'MMP23B', 'HMGCS2', 'TNFRSF4', 'OR2C3', 'DVL1', 'MXRA8', 'FCRL1', 'NADK', 'SERTAD4', 'GCLM', 'GBP5', 'OR14A2', 'GNG12', 'OR4F16', 'OR2L5', 'COL11A1', 'ATAD3B', 'MT1HL1', 'MUC1', 'AMY1C', 'PLPPR5', 'PANK4', 'RNF223', 'NOTCH2', 'OR14I1', 'FLG', 'EDN2', 'NEGR1', 'COL24A1', 'B3GALT6', 'SDF4', 'ARHGEF16', 'PUSL1', 'ACAP3', 'CFHR5', 'OR2T2', 'AMER3', 'HOXD8', 'PARD3B', 'TPO', 'PAIP2B', 'BAZ2B', 'CYP26B1', 'FASTKD1', 'VSNL1', 'C2CD6', 'RGPD2', 'FN1', 'CCDC138', 'SERPINE2', 'KYNU', 'IHH', 'RGPD4', 'SCN7A', 'SNTG2', 'RBMS1', 'PKDCC', 'THADA', 'POTEE', 'AQP12A', 'MTLN', 'MREG', 'SCN3A', 'METTL8', 'DCAF17', 'POU3F3', 'PLGLB2', 'ANKMY1', 'PLGLB1', 'TTC30A', 'TTC30B', 'LYG2', 'FIGN', 'RAPH1', 'CHRND', 'WDR12', 'NBEAL1', 'GPN1', 'COL3A1', 'CFC1', 'FLACC1', 'HOXD11', 'EPB41L5', 'COX5B', 'ADAM17', 'SP3', 'GAREM2', 'MAP2', 'BUB1', 'TMEM178A', 'FAM237A', 'D2HGDH', 'POTEJ', 'CNNM3', 'SULT1C2', 'FILIP1L', 'IL20RB', 'RAP2B', 'PLAAT1', 'BDH1', 'CHST2', 'LMLN', 'IQCG', 'MTRNR2L12', 'GAP43', 'AGTR1', 'NECTIN3', 'STXBP5L', 'CPB1', 'ESYT3', 'ATP1B3', 'COLQ', 'RPL35A', 'TBC1D5', 'EPHA6', 'ROBO1', 'NLGN1', 'PLSCR1', 'OR5AC2', 'DNAJB8', 'KALRN', 'APOD', 'ZBBX', 'DSPP', 'SGMS2', 'SLC26A1', 'HNRNPD', 'PLRG1', 'CXCL13', 'TMEM271', 'DUX4', 'RBM46', 'KIAA0232', 'CXCL2', 'WDR1', 'HMX1', 'PCGF3', 'TAPT1', 'SLC25A31', 'LCORL', 'CXCL5', 'FGFRL1', 'FRG2', 'IRX4', 'TERT', 'TAF11L6', 'CDH10', 'SMN2', 'TPPP', 'PRLR', 'PDLIM7', 'MEF2C', 'FLT4', 'MINAR2', 'SLC9A3', 'TAF11L3', 'TAF11L9', 'TAF11L4', 'TAF11L10', 'SLCO6A1', 'SLCO4C1', 'FNIP1', 'H3Y2', 'NKD2', 'DOCK2', 'SV2C', 'MCTP1', 'SMN1', 'ADCY2', 'EXOC3', 'FAM153B', 'HNRNPH1', 'OXCT1', 'FCHO2', 'CDH18', 'RAD1', 'GTF2H2C', 'ZDHHC11B', 'CKMT2', 'CCL28', 'BASP1', 'HTR1A', 'RANBP17', 'FAM120B', 'PNISR', 'ARFGEF3', 'TIAM2', 'ENPP4', 'EFHC1', 'PAQR8', 'ARID1B', 'AFDN', 'NFYA', 'DEK', 'PLG', 'HLA-DRA', 'C4B', 'DACT2', 'HS3ST5', 'GFRAL', 'CALHM4', 'TPBG', 'OR12D3', 'CEP85L', 'PRDM1', 'ELOVL2', 'HDGFL1', 'CALHM5', 'MEP1A', 'PTCHD4', 'BRPF3', 'CLDN20', 'RIMS1', 'RNF144B', 'PHF10', 'RGS17', 'THBS2', 'PHACTR1', 'BTN2A1', 'KIF25', 'ATG5', 'TMEM170B', 'TRAM2', 'PPP1R3G', 'BMP6', 'TAAR6', 'KIAA0408', 'TRERF1', 'LCA5', 'BEND3', 'ZKSCAN3', 'VIP', 'MCM9', 'VTA1', 'NMBR', 'OR2J3', 'OR2J2', 'DLL1', 'POM121L2', 'PGBD1', 'SPDYE17', 'POLR2J2', 'UPK3BL1', 'CTAGE15', 'NAPEPLD', 'SND1', 'OR2A42', 'CTAGE8', 'TCAF2C', 'TFEC', 'ZNF479', 'TRIM73', 'FAM71F2', 'JAZF1', 'TES', 'SPDYE13', 'MUC17', 'NPVF', 'GNAI1', 'CHRM2', 'CASTOR2', 'NCF1', 'PCLO', 'CTAGE4', 'GPR146', 'TAS2R39', 'SCIN', 'SPDYE9', 'SPDYE2B', 'SPDYE8', 'C1GALT1', 'MPP6', 'NME8', 'HIBADH', 'KCP', 'RBM48', 'PEX1', 'ARHGEF35', 'ANLN', 'CTAGE6', 'MIOS', 'BMT2', 'CNTNAP2', 'RASA4B', 'EN2', 'FAM131B', 'KIAA0895', 'ZNF804B', 'FAM86B2', 'DEFB4A', 'IQANK1', 'CYP11B2', 'CYP11B1', 'DLC1', 'FABP9', 'BMP1', 'ZFHX4', 'RSPO2', 'DEFB103A', 'ADAMDEC1', 'AGO2', 'CHD7', 'DEFA3', 'DEFA1', 'USP17L8', 'MFSD3', 'DEFB103B', 'GPIHBP1', 'DMTN', 'MMP16', 'NAPRT', 'TIGD5', 'KCNB2', 'DEFB130B', 'DEFB107A', 'TCF24', 'TMEM67', 'OXR1', 'GDAP1', 'JPH1', 'CRISPLD1', 'PRR23D2', 'ZHX1-C8orf76', 'ZHX1', 'LRRC24', 'C8orf82', 'DEFB130A', 'MSRA', 'EEF1D', 'CNGB3', 'IMPA1', 'KIF13B', 'DEFB105B', 'ZNF705D', 'TMEM249', 'SGCZ', 'RIMS2', 'ZMAT4', 'USP17L1', 'DEFB104B', 'ZNF704', 'PTK2', 'GPT', 'FAM90A10P', 'PPDPFL', 'DEFB104A', 'SPAG11B', 'SPAG11A', 'DEFA1B', 'PIWIL2', 'NKAIN3', 'CPSF1', 'DEFB106A', 'CEBPD', 'DEFB105A', 'PRR23D1', 'DEFB107B', 'MYOM2', 'DEFB4B', 'TSNARE1', 'ADGRB1', 'FOXD4L3', 'FOXD4', 'ANKRD20A1', 'ZNF658', 'SPATA31D4', 'PTBP3', 'SPATA31A6', 'ANKRD20A2P', 'PGM5', 'BARX1', 'ANKRD20A3P', 'ANP32B', 'CBWD6', 'FREM1', 'CNTNAP3B', 'GPSM1', 'RGS3', 'ADAMTSL2', 'CCDC187', 'GRK5', 'ARHGAP12', 'ZMYND11', 'NPY4R2', 'CRTAC1', 'TUBGCP2', 'FAM25C', 'NOC3L', 'PTPN20', 'UBE2D1', 'RGR', 'NKX6-2', 'SYCE1', 'PANK1', 'PTF1A', 'FAM13C', 'TUBB8',  ...

# %%
from matplotlib import ticker
x = list(hr_genes_loop_nums.keys())
y = list(hr_genes_loop_nums.values())

sns.set_style("whitegrid") 
fig, axes = plt.subplots(nrows=1, ncols=1, sharey=True)
axes.grid(False)
axes.plot(x, y, color=(166/255, 206/255, 227/255), label='hr')

# axes.xaxis.set_major_locator(ticker.MultipleLocator(4))
plt.xticks(rotation=90, fontsize=10)

# plt.ylim(0, 1)
plt.xlabel('gene_names', fontsize=10)
plt.ylabel('nums')
# plt.xlim(0, len(significants))
plt.legend()
plt.show()
