# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn2

# %%
def get_significant(file_path):
    significants = []
    with open(file_path, "r") as f:
        datas = f.readlines()
        for data in datas[1:]:
            data = data.split()
            x, y = int(int(data[1])/1000), int(int(data[3])/1000)
            p_value, q_value = float(data[5]), float(data[6])
            concat = int(data[4])
            significants.append((x, y, p_value, q_value, concat))
    return significants

def cal_significant(significants, proportion):
    test = np.array(significants)
    
    def _filter(_values, max_nums, test):
        values_sort_index = _values.argsort()
        values_min_numbers_index = values_sort_index[max_nums-1]
        p = max_nums
        values_min_indexs = _values.argsort()[:p-1]
        _test = test[values_min_indexs, :]
        return _test

    _p_values = test[:, 2]
    _test = _filter(_p_values, int(_p_values.shape[0]*proportion), test)
    _q_values = _test[:, 3]
    _test = _filter(_q_values, int(_q_values.shape[0]*proportion), _test)
    return _test

def cal_significant_test(significants, proportion):
    test = np.array(significants)

    test = test[np.argsort(test[:, 2])]
    _test = np.zeros((int(test.shape[0]*proportion), 5))
    significant_set = set()
    index = 0
    for i in range(test.shape[0]):
        x, y = int(test[i, 0]), int(test[i, 1])
        flag = False
        for _x in range(x-4, x+5):
            for _y in range(y-4, y+5):
                if (_x, _y) in significant_set:
                    flag = True
                    break
            if flag:
                break
        if flag:
            continue
        significant_set.add((x, y))
        _test[index] = test[i]
        index += 1
        if index > _test.shape[0] - 1:
            break
    
    def _filter(_values, max_nums, test):
        values_sort_index = _values.argsort()
        values_min_numbers_index = values_sort_index[max_nums-1]
        p = max_nums
        values_min_indexs = _values.argsort()[:p-1]
        _test = test[values_min_indexs, :]
        return _test

    _q_values = _test[:, 3]
    _test = _filter(_q_values, int(_q_values.shape[0]*proportion), _test)
    return _test

def show_venn(enhanced_sig_set, hr_sig_set):
    venn2(subsets = [hr_sig_set, enhanced_sig_set], set_labels = ('1kb', 'enhanced'), set_colors=((247/255, 129/255, 191/255), (51/255, 160/255, 44/255)))
    plt.show()

# %%
analyse_path = '/data1/lmh_data/MINE/GM12878_ATAC_H3K27ac_H3K4me3/analyse/HepG2_ATAC_H3K27ac_H3K4me3'
enhanced_path = os.path.join(analyse_path, 'experiment', 'loop', 'enhanced')
hr_path = os.path.join(analyse_path, 'experiment', 'loop', 'hr')
auxiliary_files_path = '/data1/lmh_data/MINE/source/GM12878'
proportion = 0.015

# 未去交集的全部sig
enhanced_sigs = set()
hr_sigs = set()
# 去交集的全部sig
all_enhanced_sig = dict()
all_hr_sig = dict()
for chr in range(1, 23):
    enhanced_file_path = os.path.join(enhanced_path, 'chr{}_1000b'.format(chr), 'outputs_2_100', 'FitHiC.spline_pass1.res1000.significances.txt')
    hr_file_path = os.path.join(hr_path, 'chr{}_1000b'.format(chr), 'outputs_2_100', 'FitHiC.spline_pass1.res1000.significances.txt')
    enhanced_sig = cal_significant_test(get_significant(enhanced_file_path), proportion)
    hr_sig = cal_significant(get_significant(hr_file_path), proportion)
    
    _enhanced_sig = set(list(map(tuple, np.array(enhanced_sig)[:, :2])))
    _hr_sig = set(list(map(tuple, np.array(hr_sig)[:, :2])))
    show_venn(_enhanced_sig, _hr_sig)
    # 去交集
    new_enhanced_sig = _enhanced_sig - _hr_sig
    new_hr_sig = _hr_sig - _enhanced_sig
    
    all_enhanced_sig[chr] = new_enhanced_sig
    all_hr_sig[chr] = new_hr_sig
    
    for sig in _enhanced_sig:
        _sig = list(sig)
        _sig.append('chr{}'.format(chr))
        enhanced_sigs.add(tuple(_sig))
    for sig in _hr_sig:
        _sig = list(sig)
        _sig.append('chr{}'.format(chr))
        hr_sigs.add(tuple(_sig))

# %%
show_venn(enhanced_sigs, hr_sigs)

# %%
attentions = 50
center = attentions - 1

def read_chiqseq_file(path):
    _peaks = dict()
    with open(path)as f:
        for line in f:
            datas = line.strip().split()
            left, right = int(int(datas[1])/1000), int(int(datas[2])/1000)
            peaks = list(range(left, right+1))
            if datas[0] not in _peaks.keys():
                _peaks[datas[0]] = set()
            for i in peaks:
                _peaks[datas[0]].add(i)
    return _peaks

def get_hit_indicators(significants, peaks):
    distance = np.zeros(attentions*2-1)
    
    for sig in significants:
        x, y = int(sig[0]), int(sig[1])
        for i in range(attentions):
            if (x+i) in peaks or (y+i) in peaks:
                distance[center-i] += 1
            if i != 0 and((x-i) in peaks or (y-i) in peaks):
                distance[center+i] += 1
            if (x+i) in peaks or (x-i) in peaks or (y+i) in peaks or (y-i) in peaks:
                break
    return distance

def show(x, mine_result, hr_result):
    sns.set_style("whitegrid") 
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), sharey=True)
    axes.grid(False)
    axes.plot(x, mine_result, color=(51/255, 160/255, 44/255), label='mine')
    axes.plot(x, hr_result, color=(177/255, 89/255, 40/255), label='hr')

    plt.xlabel('distance')
    plt.ylabel('nums')
    plt.legend()
    plt.show()

def figure(chip_seq_path):
    all_enhanced_result = np.zeros(attentions*2-1)
    all_hr_result = np.zeros(attentions*2-1)

    for chr in range(1, 23):
        _peaks = read_chiqseq_file(chip_seq_path)
        enhanced_result = get_hit_indicators(all_enhanced_sig[chr], _peaks['chr{}'.format(chr)])
        hr_result = get_hit_indicators(all_hr_sig[chr], _peaks['chr{}'.format(chr)])

        all_enhanced_result += enhanced_result
        all_hr_result += hr_result

    show(list(range(-attentions+1, attentions)), all_enhanced_result, all_hr_result)

# %%
tss_file_path = os.path.join(auxiliary_files_path, 'Homo_sapiens.GRCh38.104.chr.gff3')

def get_tss_gene_info(gene_biotype='protein_coding'):
    gene_location = dict()
    gene_info = dict()
    with open(tss_file_path, "r") as f:
        datas = f.readlines()
        for data in datas[9:]:
            data = data.split('\t')
            if len(data) < 9:
                continue
            if data[2] != 'gene' or data[8].find(gene_biotype) == -1:
                continue
            if data[6] == '+':
                _location = data[3]
            elif data[6] == '-':
                _location = data[4]
            else:
                print('error')
            if not data[0].isdigit():
                continue
            chromosome = int(data[0])
            if chromosome not in gene_location:
                gene_location[chromosome] = set()
            gene_location[chromosome].add(int(int(_location)/1000))
            
            _tmp = data[-1].split('Name=')
            if len(_tmp) < 2:
                continue
            gene_names = _tmp[1].split(';')[0]
            gene_ids = data[-1].split('ID=')[1].split(',')[0].split(';')[0]
            
            if chromosome not in gene_info:
                gene_info[chromosome] = set()
            gene_info[chromosome].add((int(int(_location)/1000), gene_names, gene_ids, data[-1].replace('\n', '')))
    return gene_location, gene_info

def figure_tss(locations):
    all_enhanced_result = np.zeros(attentions*2-1)
    all_hr_result = np.zeros(attentions*2-1)

    for chr in range(1, 23):
        if chr not in locations:
            continue
        enhanced_result = get_hit_indicators(all_enhanced_sig[chr], locations[chr])
        hr_result = get_hit_indicators(all_hr_sig[chr], locations[chr])

        all_enhanced_result += enhanced_result
        all_hr_result += hr_result

    show(list(range(-attentions+1, attentions)), all_enhanced_result, all_hr_result)

# %%
figure_tss(get_tss_gene_info('protein_coding')[0])

# %%
figure_tss(get_tss_gene_info('pseudogene')[0])

# %%
def get_hit_genes(significants, gene_info, genes_loop_nums):
    genes = set()
    for sig in significants:
        x, y = int(sig[0]), int(sig[1])
        for _info in gene_info:
            if abs(x-_info[0])<3 or abs(y-_info[0])<3:
                if _info[1] not in genes_loop_nums:
                    genes_loop_nums[_info[1]] = 1
                else:
                    genes_loop_nums[_info[1]] += 1
                genes.add((_info[1], _info[2], _info[3]))
    return genes, genes_loop_nums

def get_hit_gene_names(significants, gene_biotype='protein_coding'):
    gene_info = get_tss_gene_info(gene_biotype)[1]
    all_genes = set()
    genes_loop_nums = dict()
    for chr in range(1, 23):
        genes, genes_loop_nums = get_hit_genes(significants[chr], gene_info[chr], genes_loop_nums)
        all_genes = all_genes | genes
    return all_genes, genes_loop_nums

# %%
mine_hit_genes, mine_genes_loop_nums = get_hit_gene_names(all_enhanced_sig, gene_biotype='protein_coding')
mine_hit_genes = list(mine_hit_genes)
mine_hit_genes = np.array(mine_hit_genes)
print(len(mine_hit_genes))
print(mine_genes_loop_nums.keys())
# Out:
# 2075
# dict_keys(['MCL1', 'AKR1A1', 'SRGAP2B', 'FAM72D', 'PPIAL4A', 'RUSC1', 'MLLT11', 'PRKAB2', 'CDK11A', 'CDK11B', 'RAB42', 'GLMP', 'TMEM79', 'SMG5', 'PPM1J', 'KHDC4', 'HCN3', 'CLK2', 'TRNP1', 'PEX19', 'CCNL2', 'VWA1', 'GPR89A', 'SLC35E2B', 'PRPF3', 'RBM8A', 'PSMD4', 'CYB561D1', 'S100A10', 'TRNAU1AP', 'SEMA6C', 'TARS2', 'TXNIP', 'CA14', 'GNB1', 'TRIM46', 'KRTCAP2', 'ZNF124', 'FCGR1B', 'ILF2', 'MSTO1', 'SCNM1', 'TNFAIP8L2', 'MRPS21', 'FMO5', 'CHD1L', 'GPR89B', 'FAM72B', 'SRGAP2C', 'SRSF10', 'C1orf43', 'UBAP2L', 'NBPF12', 'CELA3B', 'CTTNBP2NL', 'ODR4', 'TPR', 'SYNC', 'NPR1', 'HJV', 'FDPS', 'NBPF15', 'ENSA', 'PPIAL4G', 'MEF2D', 'MRPL20', 'INTS3', 'ELK4', 'NUAK2', 'RPRD2', 'POLR3GL', 'ANKRD34A', 'PDIK1L', 'CITED4', 'NOTCH2NLC', 'ACOT7', 'PEX11B', 'NBPF9', 'MOV10', 'MPC2', 'NRAS', 'PDZK1', 'LCE1C', 'LCE1E', 'LIX1L', 'DAP3', 'YY1AP1', 'S100A2', 'ANKRD35', 'RFX5', 'NBPF19', 'PRRC2C', 'ANXA9', 'PKLR', 'SF3B4', 'H2AC20', 'BOLA1', 'H2BC21', 'H2AC21', 'RXFP4', 'UQCRH', 'LRRC41', 'GLRX2', 'SORT1', 'IL6R', 'PPP2R5A', 'ATAD3B', 'SEMA4A', 'CD160', 'PHGDH', 'ZNF697', 'NOTCH2NLR', 'NBPF26', 'NBPF11', 'AGRN', 'H3-3A', 'SSU72', 'NBPF20', 'PRUNE1', 'MINDY1', 'CERS2', 'EFNA1', 'MIB2', 'LUZP1', 'PINK1', 'PPIAL4C', 'FCGR2B', 'FCGR1A', 'PPIAL4D', 'NSUN4', 'NUDC', 'GPATCH3', 'PRDX1', 'EXO5', 'FCGR3B', 'CIART', 'KIF2C', 'YIPF1', 'SEPTIN10', 'SOWAHC', 'VIL1', 'RAB11FIP5', 'NT5DC4', 'POLR1B', 'ZNF513', 'MRPS5', 'EPCAM', 'APOB', 'SLC23A3', 'EFHD1', 'HNRNPLL', 'GALM', 'CGREF1', 'TMBIM1', 'COX5B', 'CYP27A1', 'NDUFB3', 'FAM126B', 'BMPR2', 'ATL2', 'LIMS1', 'MTERF4', 'PASK', 'CFLAR', 'TTL', 'HDLBP', 'SEPTIN2', 'TFPI', 'MERTK', 'C2orf42', 'TIA1', 'ANKRD36B', 'IFT172', 'FIGLA', 'PCBP1', 'PREB', 'DIS3L2', 'MAP4K3', 'SLC5A6', 'ATRAID', 'TMEM127', 'CIAO1', 'STARD7', 'HNRNPA3', 'PDCD1', 'GREB1', 'SLC11A1', 'RNF103', 'ANKRD39', 'ANKRD23', 'COQ10B', 'PPP1R7', 'MAPRE3', 'ITGAV', 'INHA', 'OBSL1', 'TDRD15', 'MPV17', 'C2orf81', 'MOGS', 'WDR54', 'PRLH', 'KLHL23', 'CCDC173', 'PHOSPHO2', 'WDFY1', 'MATN3', 'AGAP1', 'HK2', 'STK39', 'FABP1', 'STK11IP', 'TMEM198', 'CHPF', 'WDR33', 'FASTKD1', 'HSPE1-MOB4', 'HSPE1', 'EIF2B4', 'SNX17', 'ZC3H6', 'BZW1', 'CATIP', 'ATOH8', 'SLC1A4', 'KRCC1', 'SMYD1', 'NDUFAF7', 'CEBPZ', 'BOK', 'CD8B', 'CD8A', 'COPS9', 'CTDSP1', 'DTNB', 'EML4', 'DPYSL5', 'SULT6B1', 'CEBPZOS', 'HNMT', 'MEMO1', 'SPAST', 'INSIG2', 'SOCS5', 'ACOXL', 'BUB1', 'MRPL53', 'RAB10', 'EIF5B', 'TXNDC9', 'MALL', 'E2F6', 'FZD5', 'ORC2', 'SF3B1', 'SEMA4C', 'MZT2A', 'CCDC74A', 'SLC20A1', 'NPHP1', 'ZC3H8', 'MRPL44', 'LAPTM4A', 'FAHD2B', 'TBC1D8', 'CNOT11', 'RETREG2', 'CNPPD1', 'ABCB6', 'PRKAG3', 'PCYOX1', 'ZNF514', 'ZNF2', 'D2HGDH', 'KCMF1', 'COBLL1', 'CASP8', 'SPRED2', 'ID2', 'USP39', 'GGCX', 'VAMP8', 'TMEM150A', 'NEURL3', 'CASP10', 'NBEAL1', 'WDR12', 'IHH', 'GPR17', 'GTF3C2', 'ZFP36L2', 'C2orf92', 'ACTR1B', 'TCF23', 'NPAS2', 'ABHD1', 'CKAP2L', 'TGFA', 'PTMA', 'ACSL3', 'C2orf68', 'SNRPG', 'MGAT4A', 'NEU2', 'TMEM87B', 'MYO1B', 'OTOS', 'POTEI', 'TRAF3IP1', 'EIF2AK3', 'RPIA', 'STK25', 'PDIA6', 'SERTAD2', 'NRBP1', 'GMCL1', 'NMUR1', 'TTC30B', 'THAP4', 'ATG4B', 'PECR', 'TMEM169', 'XRCC5', 'CRIM1', 'RANBP2', 'IL1R1', 'CNNM4', 'OLA1', 'HTRA2', 'AUP1', 'EVA1A', 'CLK1', 'ADRA2B', 'NAT8', 'ANAPC1', 'NFE2L2', 'AGPS', 'USP34', 'ANKRD36', 'AGFG1', 'B3GNT7', 'NHEJ1', 'ATP6V1B1', 'TMEM37', 'PSMD14', 'IMPDH2', 'IQCG', 'LMLN', 'SERPINI1', 'PDCD10', 'SNX4', 'STIMATE-MUSTN1', 'STIMATE', 'CTDSPL', 'AHSG', 'RIOX2', 'MELTF', 'TM4SF4', 'TM4SF1', 'ST3GAL6', 'LRCH3', 'GNAI2', 'GNAT1', 'ISY1-RAB43', 'RAB43', 'ISY1', 'C3orf33', 'NCEH1', 'TBCCD1', 'SHISA5', 'UTS2B', 'CCDC50', 'MAP4', 'PIK3CB', 'CIDEC', 'IL17RC', 'NBEAL2', 'CCDC12', 'IP6K1', 'QRICH1', 'TOPBP1', 'RUBCN', 'CISH', 'MAPKAPK3', 'CYP8B1', 'BDH1', 'SETD2', 'HEMK1', 'C3orf18', 'NISCH', 'TNNC1', 'SETD5', 'SLC35G2', 'NAA50', 'ATP6V1A', 'PCYT1A', 'DYNLT2B', 'EMC3', 'RBM15B', 'SLC25A20', 'SENP7', 'SCAP', 'RAB7A', 'GNB4', 'PLXNB1', 'GTF2E1', 'RABL3', 'FYTTD1', 'SMARCC1', 'SKIL', 'CDV3', 'TRAK1', 'IL17RE', 'IRAK2', 'SENP5', 'DTX3L', 'PARP9', 'HACD2', 'RHOA', 'TCTA',  ...

# %%
x = list(mine_genes_loop_nums.keys())
y = list(mine_genes_loop_nums.values())

sns.set_style("whitegrid") 
fig, axes = plt.subplots(nrows=1, ncols=1, sharey=True)
axes.grid(False)
axes.plot(x, y, color=(166/255, 206/255, 227/255), label='mine')

plt.xticks(rotation=90, fontsize=14)

# plt.ylim(0, 1)
plt.xlabel('gene_names')
plt.ylabel('nums')
# plt.xlim(0, len(significants))
plt.legend()
plt.show()

# %%
hr_hit_genes, hr_genes_loop_nums = get_hit_gene_names(all_hr_sig, gene_biotype='protein_coding')
hr_hit_genes = list(hr_hit_genes)
hr_hit_genes = np.array(hr_hit_genes)
print(len(hr_hit_genes))
print(hr_genes_loop_nums.keys())
# Out:
# 725
# dict_keys(['KIF17', 'PRAMEF10', 'PRAMEF25', 'OR2T34', 'PRAMEF33', 'OR2T3', 'EPS15', 'TNFRSF14', 'RWDD3', 'ODF2L', 'HNRNPCL3', 'LRRC8B', 'CDK11B', 'CCDC18', 'TMED5', 'BCL2L15', 'CHD5', 'PRAMEF5', 'GPSM2', 'OR2T5', 'AJAP1', 'STRIP1', 'SH3GLB1', 'PGBD2', 'COX20', 'SLC35E2B', 'TMEM52', 'PRAMEF9', 'PRAMEF18', 'NGF', 'ATAD3B', 'SKI', 'FAM131C', 'CTNNBIP1', 'SLC25A24', 'WARS2', 'NBPF9', 'PADI2', 'PRAMEF15', 'AK5', 'BCAR3', 'TRIM62', 'MMP23B', 'PANK4', 'OR2W3', 'MAP7D1', 'TRAPPC3', 'TMEM88B', 'VWA1', 'LRIF1', 'HSPG2', 'OR2C3', 'OR2L5', 'NBPF6', 'ACTRT2', 'FAAP20', 'TRIM45', 'NBPF4', 'PRAMEF14', 'PRAMEF6', 'SLC16A4', 'GNG12', 'ZNF362', 'WNT2B', 'ID3', 'GCLM', 'CCN1', 'OLFM3', 'HNRNPCL2', 'NBPF1', 'FOXD3', 'MAP2', 'ATP6V1B1', 'CFC1', 'KLHL30', 'ASB1', 'ANKRD36B', 'RIF1', 'STON1-GTF2A1L', 'STON1', 'ALK', 'AMER3', 'MOGAT1', 'FIGLA', 'MAP3K2', 'BAZ2B', 'MARCHF7', 'REV1', 'STEAP3', 'SPEG', 'GPR17', 'HOXD4', 'HOXD8', 'MZT2B', 'FAM178B', 'POTEF', 'SMPD4', 'PDCD1', 'ZAP70', 'AQP12A', 'AQP12B', 'POTEI', 'XDH', 'PCBP1', 'TWIST2', 'UGT1A8', 'ATL2', 'ILKAP', 'TMEFF2', 'STAT4', 'FAM161A', 'GAL3ST2', 'ARHGAP25', 'CAPN10', 'FOXN2', 'AGBL5', 'CROCC2', 'MTIF2', 'LYPD6', 'APLF', 'FBXO48', 'FARP2', 'SERPINE2', 'PLCL1', 'PAIP2B', 'TCF23', 'ERBB4', 'FANCL', 'EPC2', 'CCDC85A', 'TMEM178A', 'ITGB6', 'FRZB', 'MTX2', 'GPC1', 'RAPH1', 'DNAJB2', 'REG1A', 'POTEJ', 'RND3', 'MMADHC', 'GAP43', 'CLCN2', 'POLR2H', 'RIOX2', 'ROBO1', 'SLC6A1', 'RTP4', 'SLITRK3', 'SYN2', 'CMTM7', 'MCCC1', 'B4GALT4', 'TRA2B', 'OR5K1', 'C3orf85', 'MORC1', 'LIPH', 'ZNF80', 'NAALADL2', 'CADM2', 'NR1D2', 'NKIRAS1', 'GOLIM4', 'POU1F1', 'DCUN1D1', 'TIPARP', 'RETNLB', 'GBE1', 'EIF2B5', 'RFTN1', 'SSR3', 'FBLN2', 'ZCWPW2', 'AZI2', 'WDR1', 'GSX2', 'ZNF595', 'SH3BP2', 'SPINK2', 'GALNT7', 'FRG2', 'RNF4', 'PGM2', 'FGFR3', 'USP17L21', 'USP17L20', 'TXK', 'DCUN1D4', 'CDKN2AIP', 'MRFAP1', 'FAM193A', 'CTBP1', 'EXOC1L', 'USP17L25', 'TMEM271', 'NAT8L', 'USP17L5', 'HMX1', 'PACRGL', 'UVSSA', 'SH3TC1', 'TMEM129', 'USP17L13', 'SPON2', 'DUX4', 'N4BP2', 'MXD4', 'AASDH', 'DTHD1', 'BTF3', 'FAM153A', 'TENT4A', 'TRIM52', 'SMN1', 'MARCHF6', 'RASA1', 'OR2V2', 'CENPK', 'PPWD1', 'RHOBTB3', 'TLX3', 'GLRX', 'SMN2', 'OR2V1', 'DAP', 'MEF2C', 'RAPGEF6', 'PRR7', 'SLC9A3', 'ADCY2', 'NKD2', 'EXOC3', 'TAF11L10', 'TAF11L6', 'TAF11L9', 'CWC27', 'SREK1IP1', 'TPPP', 'LYSMD3', 'ADGRV1', 'FAM153B', 'ARID1B', 'RWDD1', 'ROS1', 'SIM1', 'SCML4', 'TXLNB', 'LPA', 'L3MBTL3', 'TREML1', 'ARG1', 'FAM162B', 'CCN2', 'HSF2', 'TUBE1', 'FAM229B', 'PLG', 'LRFN2', 'PRDM13', 'PTCHD4', 'TRERF1', 'DYNLT2', 'ERMARD', 'FABP7', 'EYA4', 'SUMO4', 'CDC40', 'WASF1', 'TAAR6', 'SLC22A7', 'AKAP7', 'SUPT3H', 'METTL24', 'EPHA7', 'CMTR1', 'PTPRK', 'DACT2', 'TCTE1', 'ARHGEF5', 'POLR2J2', 'CDC14C', 'SPDYE2', 'OR2A1', 'CASTOR2', 'POLR2J3', 'UPK3BL2', 'BBS9', 'RP9', 'POMZP3', 'GTF2IRD2', 'POLR2J', 'SPDYE17', 'SCIN', 'RSPH10B2', 'SPDYE6', 'MUC17', 'ZNF680', 'PARP12', 'NCF1', 'CTAGE8', 'SLC13A1', 'GNAI1', 'TMEM106B', 'UPK3BL1', 'ASL', 'OR2A7', 'POM121', 'PTPRZ1', 'RASA4', 'SPDYE16', 'TBXAS1', 'HIPK2', 'OR2A42', 'SPDYE2B', 'ATP6V0A4', 'NT5C3A', 'FAM185A', 'MFSD3', 'PPP1R16A', 'ATP6V0D2', 'SLC7A13', 'ZC2HC1A', 'MAFA', 'DEFA3', 'DEFA1', 'BHLHE22', 'USP17L1', 'CRISPLD1', 'FBXO25', 'CNGB3', 'ZNF705G', 'USP17L4', 'PLEKHA2', 'FAM110B', 'SULF1', 'DEFA1B', 'ARC', 'LY6H', 'AGO2', 'SLC39A4', 'DEFB4B', 'KIFC2', 'CYHR1', 'TSNARE1', 'CHD7', 'GPIHBP1', 'NCOA2', 'PLPP5', 'FOXB2', 'NUTM2F', 'ZNF484', 'PTBP3', 'NELFB', 'LCN6', 'LCN10', 'LCN12', 'PGM5', 'TOR4A', 'ENTPD8', 'WASHC1', 'FGD3', 'OBP2A', 'ANKRD20A1', 'KCNT1', 'ZNF782', 'EDF1', 'TUBB4B', 'CKS2', 'OR1L8', 'AGAP6', 'AKR1C4', 'PTPN20', 'MINPP1', 'GDF2', 'GPAM', 'FRG2B', 'RNLS', 'LIPJ', 'FAM25A', 'ANXA8', 'PANK1', 'NUTM2D', 'FAM25G', 'NPS', 'AKR1C8P', 'ATAD1', 'FAM25C', 'REEP3', 'JMJD1C', 'HECTD2', 'SGMS1', 'NUTM2A', 'MICAL2', 'DENND5A', 'SCN3B', 'PHF21A', 'BRSK2', 'GUCY1A2', 'MRGPRG', 'OR5D3P', 'OR4P4', 'PITPNM1', 'PTPRCAP', 'ARHGAP32', 'TMEM134', 'NOX4', 'MMP26', 'OR4C6', 'PSMD13', 'SIRT3', 'SYTL2', 'CARNS1', 'RPS6KB2', 'TEAD1', 'MRGPRE ...

# %%
from matplotlib import ticker
x = list(hr_genes_loop_nums.keys())
y = list(hr_genes_loop_nums.values())

sns.set_style("whitegrid") 
fig, axes = plt.subplots(nrows=1, ncols=1, sharey=True)
axes.grid(False)
axes.plot(x, y, color=(166/255, 206/255, 227/255), label='hr')

# axes.xaxis.set_major_locator(ticker.MultipleLocator(4))
plt.xticks(rotation=90, fontsize=10)

# plt.ylim(0, 1)
plt.xlabel('gene_names', fontsize=10)
plt.ylabel('nums')
# plt.xlim(0, len(significants))
plt.legend()
plt.show()

# %%
np.save('temp/HepG2_ATAC_H3K27ac_H3K4me3_2_100_all_enhanced_sig.npy', all_enhanced_sig)
np.save('temp/HepG2_ATAC_H3K27ac_H3K4me3_2_100_all_hr_sig.npy', all_hr_sig)
