# %%
library("rGMAP")

# %%
hr = rGMAP("/data1/lmh_data/MMSR_complete/draw/rGAMP/hr_chr19_1000b_down.txt", resl = 25000)
complete = rGMAP("/data1/lmh_data/MMSR_complete/draw/rGAMP/replaced_chr19_1000b_down.txt", resl = 25000)
enhanced = rGMAP("/data1/lmh_data/MMSR_complete/draw/rGAMP/replaced_chr19_result_down.txt", resl = 25000)
# low5 = rGMAP("/data1/lmh_data/MMSR_complete/draw/rGAMP/chr19_low5.txt", resl = 1000)
# low10 = rGMAP("/data1/lmh_data/MMSR_complete/draw/rGAMP/chr19_low10.txt", resl = 1000)
# Out:
# Read hic_obj...
#
# Note that the input hic map should be just for a single chromosome, since no index_obj was provided.
#
# >>>> call TADs...
#
# Trying using models with different variances
#
# No models can be fitted, using 75% quantile as cutoff
#
# >>>> call sub-domains for 1th domain of order 1...
#
# start from bin 1 to bin 40
#
# >>> no sub-TADs found!
#
# >>>> call sub-domains for 3th domain of order 1...
#
# start from bin 50 to bin 74
#
# >>> no sub-TADs found!
#
# >>>> call sub-domains for 4th domain of order 1...
#
# start from bin 74 to bin 96
#
# >>> no sub-TADs found!
#
# >>>> call sub-domains for 6th domain of order 1...
#
# start from bin 103 to bin 127
#
# d = 8, dp = 5, t1 = 0.957, t2 = 1.645
#
# >>>> call sub-domains for 7th domain of order 1...
#
# start from bin 127 to bin 167
#
# >>> no sub-TADs found!
#
# >>>> call sub-domains for 9th domain of order 1...
#
# start from bin 255 to bin 315
#
# >>> no sub-TADs found!
#
# ...

# %%
write.table(hr$hierTads, "TAD_mark/hr_down.txt", quote = FALSE, sep = "\t", row.names = FALSE)
write.table(complete$hierTads, "TAD_mark/complete_down.txt", quote = FALSE, sep = "\t", row.names = FALSE)
write.table(enhanced$hierTads, "TAD_mark/enhanced_down.txt", quote = FALSE, sep = "\t", row.names = FALSE)
# write.table(low5$hierTads, "TAD_mark/low5.txt", quote = FALSE, sep = "\t", row.names = FALSE)
# write.table(low10$hierTads, "TAD_mark/low10.txt", quote = FALSE, sep = "\t", row.names = FALSE)
