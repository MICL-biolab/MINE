# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn2

# %%
def get_significant(file_path):
    significants = []
    with open(file_path, "r") as f:
        datas = f.readlines()
        for data in datas[1:]:
            data = data.split()
            x, y = int(int(data[1])/1000), int(int(data[3])/1000)
            p_value, q_value = float(data[5]), float(data[6])
            concat = int(data[4])
            significants.append((x, y, p_value, q_value, concat))
    return significants

def cal_significant(significants, proportion):
    test = np.array(significants)
    
    def _filter(_values, max_nums, test):
        values_sort_index = _values.argsort()
        values_min_numbers_index = values_sort_index[max_nums-1]
        p = max_nums
#         while True:
#             if _values[values_min_numbers_index] < _values[values_sort_index[p]]:
#                 break
#             p += 1
        values_min_indexs = _values.argsort()[:p-1]
        _test = test[values_min_indexs, :]
        return _test

    _p_values = test[:, 2]
    _test = _filter(_p_values, int(_p_values.shape[0]*proportion), test)
    _q_values = _test[:, 3]
    _test = _filter(_q_values, int(_q_values.shape[0]*proportion), _test)
    return _test

def show_venn(enhanced_sig_set, hr_sig_set):
    venn2(subsets = [hr_sig_set, enhanced_sig_set], set_labels = ('1kb', 'enhanced'), set_colors=((247/255, 129/255, 191/255), (51/255, 160/255, 44/255)))
    plt.show()

# %%
analyse_path = '/data1/lmh_data/MMSR_complete/analyse/GM12878/analyse'
enhanced_path = os.path.join(analyse_path, 'experiment_diff_loop', 'loop', 'enhanced')
hr_path = os.path.join(analyse_path, 'experiment_diff_loop', 'loop', 'hr')
proportion = 0.015

# 未去交集的全部sig
enhanced_sigs = set()
hr_sigs = set()
# 去交集的全部sig
all_enhanced_sig = dict()
all_hr_sig = dict()
for chr in range(1, 23):
    enhanced_file_path = os.path.join(enhanced_path, 'chr{}_1000b'.format(chr), 'outputs', 'FitHiC.spline_pass1.res1000.significances.txt')
    hr_file_path = os.path.join(hr_path, 'chr{}_1000b'.format(chr), 'outputs', 'FitHiC.spline_pass1.res1000.significances.txt')
    enhanced_sig = cal_significant(get_significant(enhanced_file_path), proportion)
    hr_sig = cal_significant(get_significant(hr_file_path), proportion)
    
    _enhanced_sig = set(list(map(tuple, np.array(enhanced_sig)[:, :2])))
    _hr_sig = set(list(map(tuple, np.array(hr_sig)[:, :2])))
    show_venn(_enhanced_sig, _hr_sig)
    # 去交集
    new_enhanced_sig = _enhanced_sig - _hr_sig
    new_hr_sig = _hr_sig - _enhanced_sig
    
    all_enhanced_sig[chr] = new_enhanced_sig
    all_hr_sig[chr] = new_hr_sig
    
    for sig in _enhanced_sig:
        _sig = list(sig)
        _sig.append('chr{}'.format(chr))
        enhanced_sigs.add(tuple(_sig))
    for sig in _hr_sig:
        _sig = list(sig)
        _sig.append('chr{}'.format(chr))
        hr_sigs.add(tuple(_sig))

# %%
show_venn(enhanced_sigs, hr_sigs)

_enhanced_sigs = enhanced_sigs.copy()
_hr_sigs = set()
for _hr_sig in hr_sigs:
    flag = False
    for _enhanced_sig in _enhanced_sigs:
        if abs(_hr_sig[0]-_enhanced_sig[0])<3 and abs(_hr_sig[1]-_enhanced_sig[1])<3:
            _hr_sigs.add(_enhanced_sig)
            flag = True
    _hr_sigs.add(_hr_sig)
    if flag:
        _enhanced_sigs.add(_hr_sig)

show_venn(_enhanced_sigs, _hr_sigs)

# %%
attentions = 50
center = attentions - 1

def read_chiqseq_file(path):
    _peaks = dict()
    with open(path)as f:
        for line in f:
            datas = line.strip().split()
            left, right = int(int(datas[1])/1000), int(int(datas[2])/1000)
            peaks = list(range(left, right+1))
            if datas[0] not in _peaks.keys():
                _peaks[datas[0]] = set()
            for i in peaks:
                _peaks[datas[0]].add(i)
    return _peaks

def get_hit_indicators(significants, peaks):
    distance = np.zeros(attentions*2-1)
    
    for sig in significants:
        x, y = int(sig[0]), int(sig[1])
        for i in range(attentions):
            if (x+i) in peaks or (y+i) in peaks:
                distance[center-i] += 1
            if i != 0 and((x-i) in peaks or (y-i) in peaks):
                distance[center+i] += 1
            if (x+i) in peaks or (x-i) in peaks or (y+i) in peaks or (y-i) in peaks:
                break
    return distance

def show(x, mine_result, hr_result):
    sns.set_style("whitegrid") 
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), sharey=True)
    axes.grid(False)
    axes.plot(x, mine_result, color=(51/255, 160/255, 44/255), label='mine')
    axes.plot(x, hr_result, color=(177/255, 89/255, 40/255), label='hr')

    plt.xlabel('distance')
    plt.ylabel('nums')
    plt.legend()
    plt.show()

def figure(chip_seq_path):
    all_enhanced_result = np.zeros(attentions*2-1)
    all_hr_result = np.zeros(attentions*2-1)

    for chr in range(1, 23):
        _peaks = read_chiqseq_file(chip_seq_path)
        enhanced_result = get_hit_indicators(all_enhanced_sig[chr], _peaks['chr{}'.format(chr)])
        hr_result = get_hit_indicators(all_hr_sig[chr], _peaks['chr{}'.format(chr)])

        all_enhanced_result += enhanced_result
        all_hr_result += hr_result

    show(list(range(-attentions+1, attentions)), all_enhanced_result, all_hr_result)

# %%
chip_seq_path = os.path.join(analyse_path, 'experiment_diff_loop', 'auxiliary_files', 'H3K27ac_peaks.bed')
figure(chip_seq_path)

# %%
chip_seq_path = os.path.join(analyse_path, 'experiment_diff_loop', 'auxiliary_files', 'H3K4me1_peaks.bed')
figure(chip_seq_path)

# %%
chip_seq_path = os.path.join(analyse_path, 'experiment_diff_loop', 'auxiliary_files', 'H3K4me3_peaks.bed')
figure(chip_seq_path)

# %%
chip_seq_path = os.path.join(analyse_path, 'experiment_diff_loop', 'auxiliary_files', 'CTCF_peaks.bed')
figure(chip_seq_path)

# %%
chip_seq_path = os.path.join(analyse_path, 'experiment_diff_loop', 'auxiliary_files', 'RAD21_peaks.bed')
figure(chip_seq_path)

# %%
chip_seq_path = os.path.join(analyse_path, 'experiment_diff_loop', 'auxiliary_files', 'SMC3_peaks.bed')
figure(chip_seq_path)

# %%
chip_seq_path = os.path.join(analyse_path, 'experiment_diff_loop', 'auxiliary_files', 'POLR2A_peaks.bed')
figure(chip_seq_path)

# %%
tss_file_path = '/data1/lmh_data/MMSR_complete/analyse/GM12878/analyse/experiment_diff_loop/auxiliary_files/Homo_sapiens.GRCh38.104.chr.gff3'

def get_tss_gene_info(gene_biotype='protein_coding'):
    gene_location = dict()
    gene_info = dict()
    with open(tss_file_path, "r") as f:
        datas = f.readlines()
        for data in datas[9:]:
            data = data.split('\t')
            if len(data) < 9:
                continue
            if data[2] != 'gene' or data[8].find(gene_biotype) == -1:
                continue
            if data[6] == '+':
                _location = data[3]
            elif data[6] == '-':
                _location = data[4]
            else:
                print('error')
            if not data[0].isdigit():
                continue
            chromosome = int(data[0])
            if chromosome not in gene_location:
                gene_location[chromosome] = set()
            gene_location[chromosome].add(int(int(_location)/1000))
            
            _tmp = data[-1].split('Name=')
            if len(_tmp) < 2:
                continue
            gene_names = _tmp[1].split(';')[0]
            gene_ids = data[-1].split('ID=')[1].split(',')[0].split(';')[0]
            
            if chromosome not in gene_info:
                gene_info[chromosome] = set()
            gene_info[chromosome].add((int(int(_location)/1000), gene_names, gene_ids, data[-1].replace('\n', '')))
    return gene_location, gene_info

def figure_tss(locations):
    all_enhanced_result = np.zeros(attentions*2-1)
    all_hr_result = np.zeros(attentions*2-1)

    for chr in range(1, 23):
        if chr not in locations:
            continue
        enhanced_result = get_hit_indicators(all_enhanced_sig[chr], locations[chr])
        hr_result = get_hit_indicators(all_hr_sig[chr], locations[chr])

        all_enhanced_result += enhanced_result
        all_hr_result += hr_result

    show(list(range(-attentions+1, attentions)), all_enhanced_result, all_hr_result)

# %%
figure_tss(get_tss_gene_info('protein_coding')[0])

# %%
figure_tss(get_tss_gene_info('pseudogene')[0])

# %%
def get_hit_genes(significants, gene_info):
    genes = set()
    for sig in significants:
        x, y = int(sig[0]), int(sig[1])
        for _info in gene_info:
            if abs(x-_info[0])<3 or abs(y-_info[0])<3:
                genes.add((_info[1], _info[2], _info[3]))
    return genes

def get_hit_gene_names(significants, gene_biotype='protein_coding'):
    gene_info = get_tss_gene_info(gene_biotype)[1]
    all_genes = set()
    for chr in range(1, 23):
        all_genes = all_genes | get_hit_genes(significants[chr], gene_info[chr])
    return all_genes

# %%
mine_hit_genes = get_hit_gene_names(all_enhanced_sig, gene_biotype='protein_coding')
mine_hit_genes = list(mine_hit_genes)
mine_hit_genes = np.array(mine_hit_genes)
np.savetxt("genes.txt", mine_hit_genes, delimiter="\t", fmt = '%s')

# %%
mine_hit_genes
# Out:
# array([['CCL4L2', 'gene:ENSG00000276070',
#         'ID=gene:ENSG00000276070;Name=CCL4L2;biotype=protein_coding;description=C-C motif chemokine ligand 4 like 2 [Source:HGNC Symbol%3BAcc:HGNC:24066];gene_id=ENSG00000276070;logic_name=ensembl_havana_gene_homo_sapiens;version=5'],
#        ['ZNF681', 'gene:ENSG00000196172',
#         'ID=gene:ENSG00000196172;Name=ZNF681;biotype=protein_coding;description=zinc finger protein 681 [Source:HGNC Symbol%3BAcc:HGNC:26457];gene_id=ENSG00000196172;logic_name=ensembl_havana_gene_homo_sapiens;version=9'],
#        ['CCL3L1', 'gene:ENSG00000276085',
#         'ID=gene:ENSG00000276085;Name=CCL3L1;biotype=protein_coding;description=C-C motif chemokine ligand 3 like 1 [Source:HGNC Symbol%3BAcc:HGNC:10628];gene_id=ENSG00000276085;logic_name=ensembl_havana_gene_homo_sapiens;version=1'],
#        ['OR4A5', 'gene:ENSG00000221840',
#         'ID=gene:ENSG00000221840;Name=OR4A5;biotype=protein_coding;description=olfactory receptor family 4 subfamily A member 5 [Source:HGNC Symbol%3BAcc:HGNC:15162];gene_id=ENSG00000221840;logic_name=ensembl_havana_gene_homo_sapiens;version=4'],
#        ['OR4F4', 'gene:ENSG00000177693',
#         'ID=gene:ENSG00000177693;Name=OR4F4;biotype=protein_coding;description=olfactory receptor family 4 subfamily F member 4 [Source:HGNC Symbol%3BAcc:HGNC:8301];gene_id=ENSG00000177693;logic_name=ensembl_havana_gene_homo_sapiens;version=5'],
#        ['HFE', 'gene:ENSG00000010704',
#         'ID=gene:ENSG00000010704;Name=HFE;biotype=protein_coding;description=homeostatic iron regulator [Source:HGNC Symbol%3BAcc:HGNC:4886];gene_id=ENSG00000010704;logic_name=ensembl_havana_gene_homo_sapiens;version=19'],
#        ['HCN1', 'gene:ENSG00000164588',
#         'ID=gene:ENSG00000164588;Name=HCN1;biotype=protein_coding;description=hyperpolarization activated cyclic nucleotide gated potassium channel 1 [Source:HGNC Symbol%3BAcc:HGNC:4845];gene_id=ENSG00000164588;logic_name=ensembl_havana_gene_homo_sapiens;version=8'],
#        ['OR4S2', 'gene:ENSG00000174982',
#         'ID=gene:ENSG00000174982;Name=OR4S2;biotype=protein_coding;description=olfactory receptor family 4 subfamily S member 2 [Source:HGNC Symbol%3BAcc:HGNC:15183];gene_id=ENSG00000174982;logic_name=ensembl_havana_gene_homo_sapiens;version=4'],
#        ['OR4C6', 'gene:ENSG00000181903',
#         'ID=gene:ENSG00000181903;Name=OR4C6;biotype=protein_coding;description=olfactory receptor family 4 subfamily C member 6 [Source:HGNC Symbol%3BAcc:HGNC:14743];gene_id=ENSG00000181903;logic_name=ensembl_havana_gene_homo_sapiens;version=6'],
#        ['OR4A15', 'gene:ENSG00000181958',
#         'ID=gene:ENSG00000181958;Name=OR4A15;biotype=protein_coding;description=olfactory receptor family 4 subfamily A member 15 [Source:HGNC Symbol%3BAcc:HGNC:15152];gene_id=ENSG00000181958;logic_name=ensembl_havana_gene_homo_sapiens;version=5'],
#        ['C8orf33', 'gene:ENSG00000182307',
#         'ID=gene:ENSG00000182307;Name=C8orf33;biotype=protein_coding;description=chromosome 8 open reading frame 33 [Source:HGNC Symbol%3BAcc:HGNC:26104];gene_id=ENSG00000182307;logic_name=ensembl_havana_gene_homo_sapiens;version=14']],
#       dtype='<U255')

# %%
tss_file_path = '/data1/lmh_data/MMSR_complete/analyse/GM12878/analyse/experiment_diff_loop/auxiliary_files/GRCh38_latest_genomic.gff'

def get_tss_gene_info(gene_biotype='protein_coding'):
    chromosome_info = dict()
    with open(tss_file_path, "r") as f:
        datas = f.readlines()
        for data in datas[9:]:
            data = data.split('\t')
            if len(data) < 9:
                continue
            _tmp = data[-1].split('chromosome=')
            if len(_tmp) < 2:
                continue
            chromosome = _tmp[1].split(';')[0]
            if chromosome.isdigit():
                chromosome_info[data[0]] = int(chromosome)
    
    gene_location = dict()
    gene_info = dict()
    with open(tss_file_path, "r") as f:
        datas = f.readlines()
        for data in datas[9:]:
            data = data.split('\t')
            if len(data) < 9:
                continue
            if data[2] != 'gene' or data[8].find(gene_biotype) == -1:
                continue
            if data[6] == '+':
                _location = data[3]
            elif data[6] == '-':
                _location = data[4]
            else:
                print('error')
            if data[0] not in chromosome_info:
                continue
            if chromosome_info[data[0]] not in gene_location:
                gene_location[chromosome_info[data[0]]] = set()
            gene_location[chromosome_info[data[0]]].add(int(int(_location)/1000))
            
            gene_names = data[-1].split('Name=')[1].split(';')[0]
            gene_ids = data[-1].split('GeneID:')[1].split(',')[0].split(';')[0]
            
            if chromosome_info[data[0]] not in gene_info:
                gene_info[chromosome_info[data[0]]] = set()
            gene_info[chromosome_info[data[0]]].add((int(int(_location)/1000), gene_names, gene_ids, data[-1].replace('\n', '')))
    return gene_location, gene_info

def figure_tss(locations):
    all_enhanced_result = np.zeros(attentions*2-1)
    all_hr_result = np.zeros(attentions*2-1)

    for chr in range(1, 23):
        if chr not in locations:
            continue
        enhanced_result = get_hit_indicators(all_enhanced_sig[chr], locations[chr])
        hr_result = get_hit_indicators(all_hr_sig[chr], locations[chr])

        all_enhanced_result += enhanced_result
        all_hr_result += hr_result

    show(list(range(-attentions+1, attentions)), all_enhanced_result, all_hr_result)

# %%
figure_tss(get_tss_gene_info('protein_coding')[0])

# %%
figure_tss(get_tss_gene_info('pseudogene')[0])

# %%
def get_hit_genes(significants, gene_info):
    genes = set()
    for sig in significants:
        x, y = int(sig[0]), int(sig[1])
        for _info in gene_info:
            if x == _info[0] or y == _info[0]:
                genes.add((_info[1], _info[2], _info[3]))
    return genes

def get_hit_gene_names(significants, gene_biotype='protein_coding'):
    gene_info = get_tss_gene_info(gene_biotype)[1]
    all_genes = set()
    for chr in range(1, 23):
        all_genes = all_genes | get_hit_genes(significants[chr], gene_info[chr])
    return all_genes

# %%
mine_hit_genes = get_hit_gene_names(all_enhanced_sig, gene_biotype='protein_coding')
mine_hit_genes = list(mine_hit_genes)
mine_hit_genes = np.array(mine_hit_genes)
np.savetxt("genes.txt", mine_hit_genes, delimiter="\t", fmt = '%s')

# %%
mine_hit_genes
# Out:
# array([['OR4A15', '81328',
#         'ID=gene-OR4A15;Dbxref=GeneID:81328,HGNC:HGNC:15152;Name=OR4A15;description=olfactory receptor family 4 subfamily A member 15;gbkey=Gene;gene=OR4A15;gene_biotype=protein_coding;gene_synonym=OR11-118'],
#        ['CCL3L3', '414062',
#         'ID=gene-CCL3L3;Dbxref=GeneID:414062,HGNC:HGNC:30554,MIM:609468;Name=CCL3L3;description=C-C motif chemokine ligand 3 like 3;gbkey=Gene;gene=CCL3L3;gene_biotype=protein_coding;gene_synonym=464.2,D17S1718,G0S19-2,LD78,LD78BETA,SCYA3L,SCYA3L1'],
#        ['PRDM7', '11105',
#         'ID=gene-PRDM7;Dbxref=GeneID:11105,HGNC:HGNC:9351,MIM:609759;Name=PRDM7;description=PR/SET domain 7;gbkey=Gene;gene=PRDM7;gene_biotype=protein_coding;gene_synonym=PFM4,ZNF910'],
#        ['HFE', '3077',
#         'ID=gene-HFE;Dbxref=GeneID:3077,HGNC:HGNC:4886,MIM:613609;Name=HFE;description=homeostatic iron regulator;gbkey=Gene;gene=HFE;gene_biotype=protein_coding;gene_synonym=HFE1,HH,HLA-H,MVCD7,TFQTL2'],
#        ['OR4C6', '219432',
#         'ID=gene-OR4C6;Dbxref=GeneID:219432,HGNC:HGNC:14743;Name=OR4C6;description=olfactory receptor family 4 subfamily C member 6;gbkey=Gene;gene=OR4C6;gene_biotype=protein_coding;gene_synonym=OR11-138'],
#        ['C8orf33', '65265',
#         'ID=gene-C8orf33;Dbxref=GeneID:65265,HGNC:HGNC:26104;Name=C8orf33;description=chromosome 8 open reading frame 33;gbkey=Gene;gene=C8orf33;gene_biotype=protein_coding'],
#        ['OR4F4', '26682',
#         'ID=gene-OR4F4;Dbxref=GeneID:26682,HGNC:HGNC:8301;Name=OR4F4;description=olfactory receptor family 4 subfamily F member 4;gbkey=Gene;gene=OR4F4;gene_biotype=protein_coding;gene_synonym=OLA-7501,OR4F18'],
#        ['OR4A5', '81318',
#         'ID=gene-OR4A5;Dbxref=GeneID:81318,HGNC:HGNC:15162;Name=OR4A5;description=olfactory receptor family 4 subfamily A member 5;gbkey=Gene;gene=OR4A5;gene_biotype=protein_coding;gene_synonym=OR11-111'],
#        ['CCL4L2', '9560',
#         'ID=gene-CCL4L2;Dbxref=GeneID:9560,HGNC:HGNC:24066,MIM:610757;Name=CCL4L2;description=C-C motif chemokine ligand 4 like 2;gbkey=Gene;gene=CCL4L2;gene_biotype=protein_coding;gene_synonym=AT744.2,CCL4L,SCYA4L,SCYQ4L2'],
#        ['ZNF681', '148213',
#         'ID=gene-ZNF681;Dbxref=GeneID:148213,HGNC:HGNC:26457;Name=ZNF681;description=zinc finger protein 681;gbkey=Gene;gene=ZNF681;gene_biotype=protein_coding'],
#        ['OR4S2', '219431',
#         'ID=gene-OR4S2;Dbxref=GeneID:219431,HGNC:HGNC:15183;Name=OR4S2;description=olfactory receptor family 4 subfamily S member 2;gbkey=Gene;gene=OR4S2;gene_biotype=protein_coding;gene_synonym=OR11-137,OR4S2P,OST725'],
#        ['RPSAP58', '388524',
#         'ID=gene-RPSAP58;Dbxref=GeneID:388524,HGNC:HGNC:36809;Name=RPSAP58;description=ribosomal protein SA pseudogene 58;gbkey=Gene;gene=RPSAP58;gene_biotype=protein_coding;gene_synonym=RPSA_30_1642'],
#        ['HCN1', '348980',
#         'ID=gene-HCN1;Dbxref=GeneID:348980,HGNC:HGNC:4845,MIM:602780;Name=HCN1;description=hyperpolarization activated cyclic nucleotide gated potassium channel 1;gbkey=Gene;gene=HCN1;gene_biotype=protein_coding;gene_synonym=BCNG-1,BCNG1,DEE24,EIEE24,GEFSP10,HAC-2']],
#       dtype='<U255')
